# %% [markdown]
# # Multi-Indexing
# - A multi indexing or hierarchial indexing in pandas a way to create multiple index level for rows and columns in Series or DataFrame.
# - It allows us to work with multi-dimensional data in a tabular structure.

# %% [markdown]
# ### Types of Multi-Indexing
# - pd.MultiIndex.from_tuples()
# - pd.MultiIndex.from_produt()
# - .set_index() : setting multiple columns as index

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
index_val = [('cse',2021),('cse',2022),('cse',2023),('cse',2024),\
            ('ese',2021),('ese',2022),('ese',2023),('ese',2024)]

# %%
a = pd.Series([1,2,3,4,5,6,7,8],index = index_val)
a
# Out:
# (cse, 2021)    1
# (cse, 2022)    2
# (cse, 2023)    3
# (cse, 2024)    4
# (ese, 2021)    5
# (ese, 2022)    6
# (ese, 2023)    7
# (ese, 2024)    8
# dtype: int64

# %%
a[('ese',2021)]
# Out:
# np.int64(5)

# %% [markdown]
# #### It returns error while passing single key rather than tuple
# #### a['ece]

# %% [markdown]
# # Create Multi-Index
#
# #### From Tuples

# %%
multi_index = pd.MultiIndex.from_tuples(index_val)
multi_index
# Out:
# MultiIndex([('cse', 2021),
#             ('cse', 2022),
#             ('cse', 2023),
#             ('cse', 2024),
#             ('ese', 2021),
#             ('ese', 2022),
#             ('ese', 2023),
#             ('ese', 2024)],
#            )

# %%
series_data = pd.Series([1,2,3,4,5,6,7,8],index = multi_index)
series_data
# Out:
# cse  2021    1
#      2022    2
#      2023    3
#      2024    4
# ese  2021    5
#      2022    6
#      2023    7
#      2024    8
# dtype: int64

# %%
series_data[('ese',2024)]
# Out:
# np.int64(8)

# %%
series_data['ese']
# Out:
# 2021    5
# 2022    6
# 2023    7
# 2024    8
# dtype: int64

# %% [markdown]
# #### From Products

# %%
m_i = pd.MultiIndex.from_product([['cse','ese'],[2021,2022,2023,2024]],names=['dept','year'])
m_i
# Out:
# MultiIndex([('cse', 2021),
#             ('cse', 2022),
#             ('cse', 2023),
#             ('cse', 2024),
#             ('ese', 2021),
#             ('ese', 2022),
#             ('ese', 2023),
#             ('ese', 2024)],
#            names=['dept', 'year'])

# %%
pd.DataFrame({
    'values' : [1,2,3,4,5,6,7,8]
},index= m_i)
# Out:
#            values
# dept year
# cse  2021       1
#      2022       2
#      2023       3
#      2024       4
# ese  2021       5
#      2022       6
#      2023       7
#      2024       8

# %% [markdown]
# ## Multi - Col

# %%
multi_col = pd.MultiIndex.from_product([
    ['KTM','PKR'],
    ['avg_pac','students']
])
multi_col
# Out:
# MultiIndex([('KTM',  'avg_pac'),
#             ('KTM', 'students'),
#             ('PKR',  'avg_pac'),
#             ('PKR', 'students')],
#            )

# %% [markdown]
# ## Use for both side of DF

# %%
placement = pd.DataFrame([
    ['20k',50,'25k',40],
    ['21k',45,'25k',42],
    ['25k',55,'30k',50],
    ['25k',50,'28k',48],
    ['20k',50,'25k',40],
    ['21k',45,'25k',42],
    ['25k',55,'30k',50],
    ['25k',50,'28k',48],
],index= m_i,columns=multi_col)
placement
# Out:
#               KTM              PKR
#           avg_pac students avg_pac students
# dept year
# cse  2021     20k       50     25k       40
#      2022     21k       45     25k       42
#      2023     25k       55     30k       50
#      2024     25k       50     28k       48
# ese  2021     20k       50     25k       40
#      2022     21k       45     25k       42
#      2023     25k       55     30k       50
#      2024     25k       50     28k       48

# %% [markdown]
# ## .set_index()

# %%
tips = sns.load_dataset('tips')
tips_subset = tips.set_index(['time','day'])
tips_subset
# Out:
#              total_bill   tip     sex smoker  size
# time   day
# Dinner Sun        16.99  1.01  Female     No     2
#        Sun        10.34  1.66    Male     No     3
#        Sun        21.01  3.50    Male     No     3
#        Sun        23.68  3.31    Male     No     2
#        Sun        24.59  3.61  Female     No     4
# ...                 ...   ...     ...    ...   ...
#        Sat        29.03  5.92    Male     No     3
#        Sat        27.18  2.00  Female    Yes     2
#        Sat        22.67  2.00    Male    Yes     2
#        Sat        17.82  1.75    Male     No     2
#        Thur       18.78  3.00  Female     No     2
#
# [244 rows x 5 columns]

# %%
tips_subset.loc[('Dinner','Sun')]
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14768\1310850373.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   tips_subset.loc[('Dinner','Sun')]
#             total_bill   tip     sex smoker  size
# time   day
# Dinner Sun       16.99  1.01  Female     No     2
#        Sun       10.34  1.66    Male     No     3
#        Sun       21.01  3.50    Male     No     3
#        Sun       23.68  3.31    Male     No     2
#        Sun       24.59  3.61  Female     No     4
# ...                ...   ...     ...    ...   ...
#        Sun       20.90  3.50  Female    Yes     3
#        Sun       30.46  2.00    Male    Yes     5
#        Sun       18.15  3.50  Female    Yes     3
#        Sun       23.10  4.00    Male    Yes     3
#        Sun       15.69  1.50    Male    Yes     2
#
# [76 rows x 5 columns]

# %%
tips_subset.xs('Dinner')
# Out:
#       total_bill   tip     sex smoker  size
# day
# Sun        16.99  1.01  Female     No     2
# Sun        10.34  1.66    Male     No     3
# Sun        21.01  3.50    Male     No     3
# Sun        23.68  3.31    Male     No     2
# Sun        24.59  3.61  Female     No     4
# ...          ...   ...     ...    ...   ...
# Sat        29.03  5.92    Male     No     3
# Sat        27.18  2.00  Female    Yes     2
# Sat        22.67  2.00    Male    Yes     2
# Sat        17.82  1.75    Male     No     2
# Thur       18.78  3.00  Female     No     2
#
# [176 rows x 5 columns]

# %%
tips_subset
# Out:
#              total_bill   tip     sex smoker  size
# time   day
# Dinner Sun        16.99  1.01  Female     No     2
#        Sun        10.34  1.66    Male     No     3
#        Sun        21.01  3.50    Male     No     3
#        Sun        23.68  3.31    Male     No     2
#        Sun        24.59  3.61  Female     No     4
# ...                 ...   ...     ...    ...   ...
#        Sat        29.03  5.92    Male     No     3
#        Sat        27.18  2.00  Female    Yes     2
#        Sat        22.67  2.00    Male    Yes     2
#        Sat        17.82  1.75    Male     No     2
#        Thur       18.78  3.00  Female     No     2
#
# [244 rows x 5 columns]

# %%
tips_subset.index.names= ['Time','Day']

# %%
tips_subset.rename_axis(index={'time':'day'},inplace=True)

# %%
tips_subset.index.names
# Out:
# FrozenList(['Time', 'Day'])

# %%
FrozenList(['time','day'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 FrozenList(['time','day'])
#
# NameError: name 'FrozenList' is not defined

# %% [markdown]
# ## Swaplevel

# %%
tips_subset.swaplevel('day', 'time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\indexes\multi.py:1683, in MultiIndex._get_level_number(self, level)
#    1682 try:
# -> 1683     level = self.names.index(level)
#    1684 except ValueError as err:
#
# ValueError: 'day' is not in list
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 tips_subset.swaplevel('day', 'time')
#
# File c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\frame.py:7852, in DataFrame.swaplevel(self, i, j, axis)
#    7850 if axis == 0:
#    7851     assert isinstance(result.index, MultiIndex)
# -> 7852     result.index = result.index.swaplevel(i, j)
#    7853 else:
#    7854     assert isinstance(result.columns, MultiIndex)
#
# File c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\indexes\multi.py:2533, in MultiIndex.swaplevel(self, i, j)
#    2530 new_codes = list(self.codes)
#    2531 new_names = list(self.names)
# -> 2533 i = self._get_level_number(i)
#    2534 j = self._get_level_number(j)
#    2536 new_levels[i], new_levels[j] = new_levels[j], new_levels[i]
#
# File c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\indexes\multi.py:1686, in MultiIndex._get_level_number(self, level)
#    1684 except ValueError as err:
#    1685     if not is_integer(level):
# -> 1686         raise KeyError(f"Level {level} not found") from err
#    1687     if level < 0:
#    1688         level += self.nlevels
#
# KeyError: 'Level day not found'

# %%
placement.swapaxes(axis1='dept',axis2='time')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14768\1562998552.py:1: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   placement.swapaxes(axis1='dept',axis2='time')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     579             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     580         except KeyError:
# --> 581             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'dept'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14768\1562998552.py in ?()
# ----> 1 placement.swapaxes(axis1='dept',axis2='time')
#
# c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\generic.py in ?(self, axis1, axis2, copy)
#     842             FutureWarning,
#     843             stacklevel=find_stack_level(),
#     844         )
#     845
# --> 846         i = self._get_axis_number(axis1)
#     847         j = self._get_axis_number(axis2)
#     848
#     849         if i == j:
#
# c:\Users\LENOVO\anaconda3\envs\myData\lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     577     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     578         try:
#     579             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     580         except KeyError:
# --> 581             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named dept for object type DataFrame

# %%
# axix = 0 , default : for swap index value
# axix =1 , for swap columnIndex value
placement.swaplevel(0,1),axis =1

# %% [markdown]
# ## Sort Values

# %%
placement.sort_index(level='year').swaplevel('year','dept')
# Out:
#               KTM              PKR
#           avg_pac students avg_pac students
# year dept
# 2021 cse      20k       50     25k       40
#      ese      20k       50     25k       40
# 2022 cse      21k       45     25k       42
#      ese      21k       45     25k       42
# 2023 cse      25k       55     30k       50
#      ese      25k       55     30k       50
# 2024 cse      25k       50     28k       48
#      ese      25k       50     28k       48

# %%
placement['KTM','students'].groupby(level='dept').mean()
# Out:
# dept
# cse    50.0
# ese    50.0
# Name: (KTM, students), dtype: float64

# %% [markdown]
# ## Reshaping
# - To transform structure of DF to make it more suitable for analysis and visualization.
# - To invloves changing the layout of rows and columns without altering the underlying data.
# - Common reshaping techinques:
#    - pivot_tables : summarizing data with aggregation, long-format to wide format
#    - melting : convert wide format data to lonf format
#    - stacking/unstacking : moving index levels btn rows and columns.

# %%
death = pd.read_csv("time_series_covid19_deaths_global.csv")
confirm = pd.read_csv("time_series_covid19_confirmed_global.csv")

# %%
print(death.shape,confirm.shape)
# Out:
# (289, 1081) (289, 1081)

# %%
death.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '12/24/22', '12/25/22', '12/26/22', '12/27/22', '12/28/22', '12/29/22',
#        '12/30/22', '12/31/22', '1/1/23', '1/2/23'],
#       dtype='object', length=1081)

# %%
confirm.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '12/24/22', '12/25/22', '12/26/22', '12/27/22', '12/28/22', '12/29/22',
#        '12/30/22', '12/31/22', '1/1/23', '1/2/23'],
#       dtype='object', length=1081)

# %%
death_new = death.melt(id_vars=['Province/State','Country/Region','Lat','Long'],\
           var_name='Date',value_name='Num_deaths')
death_new
# Out:
#        Province/State        Country/Region        Lat        Long     Date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         Num_deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 311248        5708
# 311249           0
# 311250        2159
# 311251        4024
# 311252        5637
#
# [311253 rows x 6 columns]

# %%
confirm_new = confirm.melt(id_vars=['Province/State','Country/Region','Lat','Long'],\
           var_name='Date',value_name='Num_deaths')
confirm_new
# Out:
#        Province/State        Country/Region        Lat        Long     Date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         Num_deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 311248      703228
# 311249         535
# 311250       11945
# 311251      334661
# 311252      259981
#
# [311253 rows x 6 columns]

# %%
death_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311253 entries, 0 to 311252
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  98007 non-null   object
#  1   Country/Region  311253 non-null  object
#  2   Lat             309099 non-null  float64
#  3   Long            309099 non-null  float64
#  4   Date            311253 non-null  object
#  5   Num_deaths      311253 non-null  int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
confirm_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311253 entries, 0 to 311252
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  98007 non-null   object
#  1   Country/Region  311253 non-null  object
#  2   Lat             309099 non-null  float64
#  3   Long            309099 non-null  float64
#  4   Date            311253 non-null  object
#  5   Num_deaths      311253 non-null  int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
final = confirm_new.merge(death_new, on = ['Province/State', 'Country/Region', 'Lat', 'Long','Date'])
final.to_csv('Covid_2019.csv')

# %% [markdown]
# ## Stacking and Unstacking
#  - stack() can't use for series obj

# %%
placement.stack(future_stack=True).stack(future_stack=True)
# Out:
# dept  year
# cse   2021  avg_pac   KTM    20k
#                       PKR    25k
#             students  KTM     50
#                       PKR     40
#       2022  avg_pac   KTM    21k
#                       PKR    25k
#             students  KTM     45
#                       PKR     42
#       2023  avg_pac   KTM    25k
#                       PKR    30k
#             students  KTM     55
#                       PKR     50
#       2024  avg_pac   KTM    25k
#                       PKR    28k
#             students  KTM     50
#                       PKR     48
# ese   2021  avg_pac   KTM    20k
#                       PKR    25k
#             students  KTM     50
#                       PKR     40
#       2022  avg_pac   KTM    21k
#                       PKR    25k
#             students  KTM     45
#                       PKR     42
#       2023  avg_pac   KTM    25k
#                       PKR    30k
#             students  KTM     55
#                       PKR     50
#       2024  avg_pac   KTM    25k
#                       PKR    28k
#             students  KTM     50
#                       PKR     48
# dtype: object

# %%
placement.unstack().unstack().unstack()
# Out:
# dept               cse  ese
#              year
# KTM avg_pac  2021  20k  20k
#              2022  21k  21k
#              2023  25k  25k
#              2024  25k  25k
#     students 2021   50   50
#              2022   45   45
#              2023   55   55
#              2024   50   50
# PKR avg_pac  2021  25k  25k
#              2022  25k  25k
#              2023  30k  30k
#              2024  28k  28k
#     students 2021   40   40
#              2022   42   42
#              2023   50   50
#              2024   48   48
