# %% [markdown]
# ### What is Data Visualization in Data Analytics?
# Data visualization is the graphical representation of data and information using visual elements like charts, graphs, maps, and dashboards. In data analytics, it's not just about making pretty pictures; it's about revealing patterns, trends, outliers, and relationships in data that might be hidden in spreadsheets or raw numbers.
#
# - Core Purpose:
#     - It helps analysts and stakeholders make sense of complex datasets quickly.
#     - Humans process visuals faster than text.
#     - Visualizations bridge the gap between data and decision-making.
# - Key Benefits:
#
#     - Insight Discovery: Spot correlations (e.g., sales increasing with marketing spend) or anomalies (e.g., a sudden drop in user engagement).
#     - Storytelling: Communicate findings to non-technical audiences, like executives or clients.
#     - Exploration: During analysis, visuals help iterate on hypotheses.
#     - Efficiency: Reduces the time needed to understand data compared to poring over tables.
#
# In analytics workflows, visualization fits into the "presentation" phase but also aids in exploratory data analysis (EDA) earlier on. For instance, in a retail analytics project, visualizing sales by region could reveal that one area outperforms others due to seasonal trends.
# - Python libraries for creating these visuals in data analytics:
#
#     - `Matplotlib`: A foundational plotting library offering fine-grained control over every aspect of a plot. It's versatile but requires more code for complex visuals.
#     - `Seaborn`: Built on Matplotlib, it simplifies creating statistical and aesthetically pleasing visualizations with less code. It's ideal for quick, publication-quality plots.
#     - `Pandas Plotting`: Built on Matplotlib, Pandas provides a convenient plotting interface directly from DataFrames, perfect for quick exploratory visuals.

# %%
# Standard imports
import pandas as pd
import numpy as np

# Visualization library imports
import matplotlib.pyplot as plt
import seaborn as sns

# A special command to make plots appear inline in Jupyter Notebook
# %matplotlib inline

# Set a default style for our plots for a nice look
sns.set_style('whitegrid')

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Product_A_Sales': [220, 250, 230, 280, 310, 290],
    'Product_B_Sales': [180, 200, 240, 210, 190, 220],
    'Customer_Satisfaction': [8.5, 8.2, 8.8, 9.0, 9.1, 8.9]
}

df = pd.DataFrame(data)

print("--- Our Sample Sales Dataset ---")
df
# Out:
# --- Our Sample Sales Dataset ---
#   Month  Product_A_Sales  Product_B_Sales  Customer_Satisfaction
# 0   Jan              220              180                    8.5
# 1   Feb              250              200                    8.2
# 2   Mar              230              240                    8.8
# 3   Apr              280              210                    9.0
# 4   May              310              190                    9.1
# 5   Jun              290              220                    8.9

# %% [markdown]
# # Line Plot
#  - this plot is used for univariate and bivariate analysis.
#  - this shows time series data over the period of time.
#  - suitable for showing market trends, product efficiency over time.
#  - 'Question:' How did sales for Prodcut A & B change over first six months?

# %%
# figure for define size of picture.
plt.figure(figsize=(15,5))


#plotting with matplotlib
plt.plot(df['Month'],df['Product_A_Sales'],linestyle="dotted",marker='o')
plt.xlabel("Months")
plt.ylabel("Sales (k $)")
plt.title(" Sample Sales ",fontsize=20)
plt.show()

# %%
# figure for define size of picture.
plt.figure(figsize=(15,5))


#plotting with matplotlib
plt.plot(df['Month'],df['Product_A_Sales'],linestyle="dotted",marker='o',label="Product A")
plt.plot(df['Month'],df['Product_B_Sales'],linestyle="dashed",marker='D',label="Product B")
plt.xlabel("Months")
plt.ylabel("Sales (k $)")
plt.title(" Monthly Sales Performance of Products ",fontsize=20)
plt.legend()
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(15,5))
sns.lineplot(tips, x='day',y='total_bill',linestyle="dashed",marker='o',hue="smoker")
plt.title('Bill generated over days',fontsize=20)
plt.xlabel('Days for Week')
# Out:
# Text(0.5, 0, 'Days for Week')

# %% [markdown]
# ## Count Plot
#  - use for unvariate analaysis and sometimes use as bivariate (barplot)
#  - show count value of categorical data points.
#  - Question: Show the total customer over days?

# %%
plt.figure(figsize=(8,4))
ax= sns.countplot(tips,x='day',hue='smoker')
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# - Highest customer engagement on saturday with 57 people
# - Highest non-smoker customer engagement on Sunday with 57.

# %% [markdown]
# # Histogram
#  - For univariate analysis to check distribution of data points.
#  -  It's for continuous datapoints
#  - It support bins to show range of data points.
#  - Question : Show the distribution of bills.

# %%
plt.figure(figsize=(15,4))
sns.histplot(tips,x='total_bill',bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# # Box-Plot
#  - univariate and unvariate analaysis with numeric or continuous data points.
#  - to find outliers, variance, distribution.
#  - 'Question' : Distribution of total bil or is there any outliers present in total_bill?

# %%
plt.figure(figsize=(15,4))
sns.boxplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # Pie-Chart
#  - It's a circular statistical graph that divides a circle into slices to illustrate numerical proportions or percentage of a whole.
#  - To display the poperties of categories within a dataset.
#  - To show dominance in categories.
#  - Question: tips per day

# %%
tip_by_day = tips.groupby('day',observed=True)[['tip']].sum().reset_index()
tip_by_day
# Out:
#     day     tip
# 0  Thur  171.83
# 1   Fri   51.96
# 2   Sat  260.40
# 3   Sun  247.39

# %%
plt.figure(figsize=(10, 5))

plt.pie(
    tip_by_day['tip'],
    labels=tip_by_day['day'],
    autopct='%.2f%%',
    startangle=90,
    explode=[0, 0.2, 0, 0],
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},
    colors=sns.color_palette('pastel')
)

plt.legend(bbox_to_anchor=(1, 1, 0.15, 0))
plt.show()

# %% [markdown]
# # Scatter Plot
#  - A scatter plot is a type of data visualization that displays individual data points as dots on a two-dimensional plane.
#  - where x & y axis represent two different variables.
#  - to show rlnship btn two numerical variables and optionally explore additional dimensions like size, color or shape.
#  - correlation, clusters, multi-value analysis.
#  - Question : show correlation btn total_bill and tip.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(tips,
                x='total_bill',
                y='tip',hue='smoker',
                size='size',
                style='sex',
                alpha=1)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # RegPlot:
#  - It's used to show scatter plot with linear line.

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='total_bill',y='tip',data=tips,scatter_kws={'alpha':0.5})
plt.title("Total billl vs Tip")
plt.show()

# %% [markdown]
# # HeatMap
#  - Visualization technique that uses color intensity to present the magnitude of values in a matrices or table.
#  - often used to correlations matrics, confusion matrics or time-series data

# %%
corr_matrix = tips[['total_bill','tip','size']].corr()
corr_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix,annot=True,fmt='.3f',vmin=-1,vmax=1,cmap='autumn',
            square=True,
            xticklabels=['total_bill','size','tip'],
            yticklabels=['total_bill','size','tip'])
# Out:
# <Axes: >

# %% [markdown]
# # SubPlot
#  - to arrange multiple plots in grid or table for comparision or to present related data.

# %%
fig,axes= plt.subplots(nrows=3,ncols=1,figsize=(10,10))

# Subplot1 : Scatter plot
sns.scatterplot(tips,x='total_bill',y='tip',ax=axes[0])
axes[0].set_title('Scatter: Total bill vs tip')
axes[0].set_xlabel('total_bill')
axes[0].set_ylabel('tips($)')

# Subplot 2 : Barplot
sns.barplot(tips,x='day',y='tip',ax = axes[1])

# Subplot 3 : piechart
plt.pie(tip_by_day['tip'],labels= tip_by_day['day'],autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26110b43b50>,
#   <matplotlib.patches.Wedge at 0x26110abae30>,
#   <matplotlib.patches.Wedge at 0x26110b54b20>,
#   <matplotlib.patches.Wedge at 0x26110b54d30>],
#  [Text(0.813884357598144, 0.7399947651551709, 'Thur'),
#   Text(-0.1405224239481115, 1.090987373147713, 'Fri'),
#   Text(-1.0943559707179313, 0.11128795691365127, 'Sat'),
#   Text(0.5354967176535845, -0.9608554862112394, 'Sun')],
#  [Text(0.4439369223262603, 0.40363350826645683, '23.49%'),
#   Text(-0.07664859488078808, 0.5950840217169343, '7.10%'),
#   Text(-0.596921438573417, 0.060702521952900684, '35.59%'),
#   Text(0.292089118720137, -0.5241029924788578, '33.82%')])

# %% [markdown]
# # FaceGrid
#  - It creates a grid of subjects based on one or more categorical vairable, enabling comparision across subsets of data.
#  - Comparing distributions or relationships categories.
#  - Multi-dimensional exploration.

# %%
fg = sns.FacetGrid(tips,row='time',col='day',hue='smoker',height=3)

# map a scatter plot to each facet
fg.map(sns.scatterplot,'total_bill','tip')

# %% [markdown]
# # Barplot:
#  - Rlnship btn categorical and contiuous data points.
#  - Use for BI or multi-variate analysis.
#  - It shows aggregrate value over categories.
#  - Question: Total Sales by days of week.

# %%
plt.figure(figsize=(10,4))
ax = sns.barplot(tips, x='day', y='total_bill',hue='smoker',errorbar='sd',capsize=0.1)
for bar in ax.containers:
    ax.bar_label(bar,fmt='%.2f', label_type='center',padding=-30)
plt.title("Avg Bill amount for smoker and non-smoker on each dat of week")
plt.legend(title='Smoker',loc='best',bbox_to_anchor=(1,1,0.15,0))
plt.show()
